# %%
import sys
sys.path.append('/home/ia368/projetos/multimodal-rag-med')

from scripts.preprocess_img_embeddings import main

# Executa o pipeline
embedding_images, output_path = main("configs/imagens_embd.yaml", batch_size=128, chunk_size=512)

# Agora você pode usar os dados
print(f"\n✓ Total de embeddings gerados: {len(embedding_images)}")
print(f"✓ Salvos em: {output_path}")
# Out:
# Processando imagens por estudo: 100%|██████████| 1780/1780 [6:47:49<00:00, 13.75s/it]
# ✓ Total imagens processadas: 377110
# ✓ Salvo em: artifacts/img_embeddings
#
# ✓ Total de embeddings gerados: 377110
# ✓ Salvos em: artifacts/img_embeddings
