# %%
import torch
from transformers import AutoModel
from transformers import AutoProcessor
import yaml
from src.dataset.mimic_dataset import MIMICDataset
from src.embeddings.text_embeddings import encode_text_findings
from src.embeddings.image_embeddings import encode_images_study

# %%
# Carrega o arquivo YAML
with open("configs/configs.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
processor = AutoProcessor.from_pretrained(config['processor']['model'], token=config['processor']['auth_token'])
dataset = MIMICDataset(config['processor']['root_folder'], tokenizer=processor.tokenizer)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
sample = dataset[42]

print("Patient:", sample["patient_id"])
print("Study:", sample["study_id"])
print("N imagens:", sample["images"].shape[0])
print("Texto Findings:", sample["text"])
print("Tokenized:", sample["tokenized_text"].input_ids.shape)
# Out:
# Patient: p10001884
# Study: s52060840
# N imagens: 2
# Texto Findings: No new focal consolidation is seen.  Mild right apical pleural thickening is
#  seen.  No pleural effusion or pneumothorax is seen. The cardiac and
#  mediastinal silhouettes are stable.  Small calcification projecting over the
#  upper chest seen on the lateral view is present since at least ___, and may relate to aortic calcification.
# Tokenized: torch.Size([1, 64])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutoModel.from_pretrained(config['processor']['model'], token=config['processor']['auth_token']).to(device)

# Gera embeddings
e_text = encode_text_findings(sample, model, device)
e_img = encode_images_study(sample, processor, model, device)

# Combina (multimodal)
alpha = 0.5
e_study = alpha * e_text + (1 - alpha) * e_img
e_study = e_study / e_study.norm(dim=-1, keepdim=True)

print("e_text:", e_text)
print("e_img:", e_img)
print("e_study:", e_study)
# Out:
# It looks like you are trying to rescale already rescaled images. If the input images have pixel values between 0 and 1, set `do_rescale=False` to avoid rescaling them again.
# e_text: tensor([[-0.0085,  0.0241, -0.0242,  ..., -0.0251, -0.0344, -0.0447]])
# e_img: tensor([[-0.0269,  0.0358,  0.0142,  ..., -0.0207,  0.0523,  0.0216]])
# e_study: tensor([[-0.0278,  0.0468, -0.0078,  ..., -0.0358,  0.0140, -0.0181]])

# %%
import sys
sys.path.append('/home/ia368/projetos/multimodal-rag-med')

from scripts.preprocess_embeddings import main

# Executa o pipeline
embeddings_data, output_path = main("configs/configs.yaml")

# Agora você pode usar os dados
print(f"\n✓ Total de embeddings gerados: {len(embeddings_data['e_study'])}")
print(f"✓ Salvos em: {output_path}")
# Out:
# Carregando configuração...
# Carregando processor e modelo...
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Usando device: cpu
# Carregando dataset...
# Processando 227835 amostras...
# Processando embeddings:   0%|          | 0/7120 [00:00<?, ?it/s]It looks like you are trying to rescale already rescaled images. If the input images have pixel values between 0 and 1, set `do_rescale=False` to avoid rescaling them again.
# Processando embeddings:   0%|          | 2/7120 [03:51<228:36:08, 115.62s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 from scripts.preprocess_embeddings import main
#       6 # Executa o pipeline
# ----> 7 embeddings_data, output_path = main("configs/configs.yaml")
#       9 # Agora você pode usar os dados
#      10 print(f"\n✓ Total de embeddings gerados: {len(embeddings_data['e_study'])}")
#
# File ~/projetos/multimodal-rag-med/scripts/preprocess_embeddings.py:147, in main(config_path)
#     141 dataset = MIMICDataset(
#     142     config['processor']['root_folder'],
#     143     tokenizer=processor.tokenizer
#     144 )
#     146 print(f"Processando {len(dataset)} amostras...")
# --> 147 embeddings_data = process_embeddings(dataset, processor, model, config, device)
#     149 output_path = config['paths']['embeddings']
#     150 print(f"Salvando embeddings em {output_path}...")
#
# File ~/projetos/multimodal-rag-med/scripts/preprocess_embeddings.py:59, in process_embeddings(dataset, processor, model, config, device, batch_size)
#      56 try:
#      57     # Gera embeddings em batch (sem processor)
#      58     e_text = encode_text_findings(batch_samples, model, device)
# ---> 59     e_img = encode_images_study(batch_samples, processor, model, device)
#      61     # Combina (multimodal)
#      62     e_study = alpha * e_text + (1 - alpha) * e_img
#
# File ~/projetos/multimodal-rag-med/src/embeddings/image_embeddings.py:77, in encode_images_study(samples, processor, model, device, chunk_size)
#      74 batch = {k: v.to(device) for k, v in batch.items()}
#      76 # usa get_image_features (projeção + normalização quando disponível)
# ---> 77 img_feats = model.get_image_features(**batch)
#      78 img_feats = img_feats / img_feats.norm(dim=-1, keepdim=True)
#      79 # get_image_features normalmente retorna torch.Tensor
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/transformers/utils/generic.py:809, in filter_out_non_signature_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     800         cls_prefix = ""
#     802     warnings.warn(
#     803         f"The following named arguments are not valid for `{cls_prefix}{func.__name__}`"
#     804         f" and were ignored: {invalid_kwargs_names}",
#     805         UserWarning,
#     806         stacklevel=2,
#     807     )
# --> 809 return func(*args, **valid_kwargs)
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/transformers/models/siglip/modeling_siglip.py:900, in SiglipModel.get_image_features(self, pixel_values, interpolate_pos_encoding, **kwargs)
#     869 @filter_out_non_signature_kwargs()
#     870 @auto_docstring
#     871 def get_image_features(
#    (...)    875     **kwargs: Unpack[TransformersKwargs],
#     876 ) -> torch.FloatTensor:
#     877     r"""
#     878     Returns:
#     879         image_features (`torch.FloatTensor` of shape `(batch_size, output_dim`): The image embeddings obtained by
#    (...)    898     ...     image_features = model.get_image_features(**inputs)
#     899     ```"""
# --> 900     vision_outputs: BaseModelOutputWithPooling = self.vision_model(
#     901         pixel_values=pixel_values,
#     902         interpolate_pos_encoding=interpolate_pos_encoding,
#     903         **kwargs,
#     904     )
#     905     pooled_output = vision_outputs.pooler_output
#     907     return pooled_output
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/transformers/utils/generic.py:918, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     916 if return_dict_passed is not None:
#     917     return_dict = return_dict_passed
# --> 918 output = func(self, *args, **kwargs)
#     919 if not return_dict and not isinstance(output, tuple):
#     920     output = output.to_tuple()
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/transformers/models/siglip/modeling_siglip.py:701, in SiglipVisionTransformer.forward(self, pixel_values, interpolate_pos_encoding, **kwargs)
#     691 @can_return_tuple
#     692 @auto_docstring
#     693 def forward(
#    (...)    697     **kwargs: Unpack[TransformersKwargs],
#     698 ) -> BaseModelOutputWithPooling:
#     699     hidden_states = self.embeddings(pixel_values, interpolate_pos_encoding=interpolate_pos_encoding)
# --> 701     encoder_outputs: BaseModelOutput = self.encoder(
#     702         inputs_embeds=hidden_states,
#     703         **kwargs,
#     704     )
#     706     last_hidden_state = encoder_outputs.last_hidden_state
#     707     last_hidden_state = self.post_layernorm(last_hidden_state)
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/transformers/models/siglip/modeling_siglip.py:559, in SiglipEncoder.forward(self, inputs_embeds, attention_mask, **kwargs)
#     557 hidden_states = inputs_embeds
#     558 for encoder_layer in self.layers:
# --> 559     hidden_states = encoder_layer(
#     560         hidden_states,
#     561         attention_mask,
#     562         **kwargs,
#     563     )
#     565 return BaseModelOutput(last_hidden_state=hidden_states)
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/transformers/models/siglip/modeling_siglip.py:449, in SiglipEncoderLayer.forward(self, hidden_states, attention_mask, **kwargs)
#     446 residual = hidden_states
#     448 hidden_states = self.layer_norm1(hidden_states)
# --> 449 hidden_states, _ = self.self_attn(
#     450     hidden_states=hidden_states,
#     451     attention_mask=attention_mask,
#     452     **kwargs,
#     453 )
#     454 hidden_states = residual + hidden_states
#     456 residual = hidden_states
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/transformers/models/siglip/modeling_siglip.py:409, in SiglipAttention.forward(self, hidden_states, attention_mask, **kwargs)
#     397 attn_output, attn_weights = attention_interface(
#     398     self,
#     399     queries,
#    (...)    405     dropout=0.0 if not self.training else self.dropout,
#     406 )
#     408 attn_output = attn_output.reshape(batch_size, seq_length, embed_dim).contiguous()
# --> 409 attn_output = self.out_proj(attn_output)
#     411 return attn_output, attn_weights
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/rag_env/lib/python3.11/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# # Teste em batch

# %%
import pandas as pd

labeled = pd.read_csv("../data/mimic_small/mimic-cxr-2.1.0-test-set-labeled.csv")

labeled.head()
# Out:
#    study_id  No Finding  Enlarged Cardiomediastinum  Cardiomegaly  \
# 0  58085167         NaN                         NaN           NaN
# 1  57798090         NaN                         1.0           1.0
# 2  50020371         1.0                         NaN           NaN
# 3  52225063         NaN                         NaN           1.0
# 4  59039129         NaN                         NaN           1.0
#
#    Lung Lesion  Airspace Opacity  Edema  Consolidation  Pneumonia  \
# 0          NaN               NaN    NaN            NaN        1.0
# 1          NaN               NaN    0.0            NaN        0.0
# 2          NaN               NaN    NaN            NaN        NaN
# 3          NaN               NaN    NaN            NaN        NaN
# 4          NaN               1.0   -1.0           -1.0        NaN
#
#    Atelectasis  Pneumothorax  Pleural Effusion  Pleural Other  Fracture  \
# 0          NaN           NaN               NaN            NaN       NaN
# 1          1.0           NaN               NaN            NaN       NaN
# 2          NaN           NaN               NaN            NaN       NaN
# 3          1.0           NaN               NaN            NaN       NaN
# 4          1.0           NaN               1.0            NaN       NaN
#
#    Support Devices
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
